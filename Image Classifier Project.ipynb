# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn
from torch import optim
from torch.autograd import Variable
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import time

from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Random transformation for train data
data_transforms = {
    'train': transforms.Compose([transforms.RandomRotation(30),
                                     transforms.RandomResizedCrop(224),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])]),
    'validation': transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])]),
    'test': transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])
}

image_datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'validation' : datasets.ImageFolder(valid_dir, transform=data_transforms['validation']),
    'test' : datasets.ImageFolder(test_dir, transform=data_transforms['test']),
}

loaders = {
    'train' : torch.utils.data.DataLoader(image_datasets['train'], batch_size=32, shuffle=True),
    'validation' : torch.utils.data.DataLoader(image_datasets['validation'], batch_size=32),
    'test' : torch.utils.data.DataLoader(image_datasets['test'], batch_size=32),
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
model = models.vgg16(pretrained=True)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freeze backpropagation
for param in model.parameters():
    param.requires_grad = False

# %%
def create_classifier(model, hidden_layers):
    replace_features = model.classifier[0].in_features
    sequential = []
    sequential.extend([nn.Linear(replace_features, hidden_layers[0]), nn.ReLU(), nn.Dropout()])
    for i in range(1, len(hidden_layers)):
        sequential.extend([nn.Linear(hidden_layers[i-1], hidden_layers[i]), nn.ReLU(), nn.Dropout()])
    
    sequential.extend([nn.Linear(hidden_layers[-1], 102)])
    model.classifier = nn.Sequential(*sequential)

# %%
learning_rate = 0.01
#original_features = model.classifier[0].in_features
momentum = 0
hidden_layers = [4096, 4096]

create_classifier(model, hidden_layers)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.classifier.parameters(), lr=learning_rate, momentum=momentum)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=102, bias=True)
#   )
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device);

# %%
def validation(model, testloader, criterion, device):
    accuracy = 0
    test_loss = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            output = model.forward(images)
            test_loss += criterion(output, labels)

            ps = torch.exp(output)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

    return test_loss, accuracy

# %%
epochs = 5
steps = 0
running_loss = 0
print_every = 5

train_losses, test_losses = [], []

def train(model, trainloader, testloader, criterion, optimizer, epochs=5, device='cpu', print_every=40,
          train_losses=None,
          test_losses=None):

    if test_losses is None:
        test_losses = []

    if train_losses is None:
        train_losses = []

    steps = 0
    running_loss = 0
    for e in range(epochs):
        model.train()
        for images, labels in trainloader:
            steps += 1
            inputs, labels = Variable(images).to(device), Variable(labels).to(device)
            optimizer.zero_grad()
            output = model.forward(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:
                model.eval()
                with torch.no_grad():
                    test_loss, accuracy = validation(model, testloader, criterion, device)

                train_losses.append(running_loss / len(trainloader))
                test_losses.append(test_loss / len(testloader))

                print("Epoch: {}/{}.. ".format(e + 1, epochs),
                      "Training Loss: {:.3f}.. ".format(running_loss / print_every),
                      "Test Loss: {:.3f}.. ".format(test_loss / len(testloader)),
                      "Test Accuracy: {:.3f}".format(accuracy / len(testloader)))

                running_loss = 0

                # Make sure dropout and grads are on for training
                model.train()


train(model, loaders['train'], loaders['validation'], criterion, optimizer, epochs, device, print_every, train_losses, test_losses)
# Out:
# Epoch: 1/5..  Training Loss: 4.648..  Test Loss: 4.596..  Test Accuracy: 0.040
# Epoch: 1/5..  Training Loss: 4.597..  Test Loss: 4.560..  Test Accuracy: 0.053
# Epoch: 1/5..  Training Loss: 4.594..  Test Loss: 4.533..  Test Accuracy: 0.043
# Epoch: 1/5..  Training Loss: 4.531..  Test Loss: 4.502..  Test Accuracy: 0.048
# Epoch: 1/5..  Training Loss: 4.490..  Test Loss: 4.468..  Test Accuracy: 0.048
# Epoch: 1/5..  Training Loss: 4.541..  Test Loss: 4.446..  Test Accuracy: 0.053
# Epoch: 1/5..  Training Loss: 4.536..  Test Loss: 4.420..  Test Accuracy: 0.069
# Epoch: 1/5..  Training Loss: 4.429..  Test Loss: 4.393..  Test Accuracy: 0.050
# Epoch: 1/5..  Training Loss: 4.443..  Test Loss: 4.370..  Test Accuracy: 0.066
# Epoch: 1/5..  Training Loss: 4.450..  Test Loss: 4.350..  Test Accuracy: 0.067
# Epoch: 1/5..  Training Loss: 4.481..  Test Loss: 4.327..  Test Accuracy: 0.095
# Epoch: 1/5..  Training Loss: 4.459..  Test Loss: 4.295..  Test Accuracy: 0.120
# Epoch: 1/5..  Training Loss: 4.507..  Test Loss: 4.272..  Test Accuracy: 0.111
# Epoch: 1/5..  Training Loss: 4.334..  Test Loss: 4.255..  Test Accuracy: 0.059
# Epoch: 1/5..  Training Loss: 4.359..  Test Loss: 4.231..  Test Accuracy: 0.123
# Epoch: 1/5..  Training Loss: 4.339..  Test Loss: 4.206..  Test Accuracy: 0.102
# Epoch: 1/5..  Training Loss: 4.312..  Test Loss: 4.185..  Test Accuracy: 0.150
# Epoch: 1/5..  Training Loss: 4.350..  Test Loss: 4.162..  Test Accuracy: 0.147
# Epoch: 1/5..  Training Loss: 4.350..  Test Loss: 4.147..  Test Accuracy: 0.173
# Epoch: 1/5..  Training Loss: 4.354..  Test Loss: 4.138..  Test Accuracy: 0.183
# Epoch: 1/5..  Training Loss: 4.320..  Test Loss: 4.112..  Test Accuracy: 0.154
# Epoch: 1/5..  Training Loss: 4.210..  Test Loss: 4.092..  Test Accuracy: 0.137
# Epoch: 1/5..  Training Loss: 4.201..  Test Loss: 4.056..  Test Accuracy: 0.157
# Epoch: 1/5..  Training Loss: 4.268..  Test Loss: 4.007..  Test Accuracy: 0.156
# Epoch: 1/5..  Training Loss: 4.173..  Test Loss: 3.978..  Test Accuracy: 0.166
# Epoch: 1/5..  Training Loss: 4.268..  Test Loss: 3.959..  Test Accuracy: 0.126
# Epoch: 1/5..  Training Loss: 4.080..  Test Loss: 3.929..  Test Accuracy: 0.145
# Epoch: 1/5..  Training Loss: 4.142..  Test Loss: 3.893..  Test Accuracy: 0.144
# Epoch: 1/5..  Training Loss: 4.187..  Test Loss: 3.861..  Test Accuracy: 0.166
# Epoch: 1/5..  Training Loss: 4.025..  Test Loss: 3.837..  Test Accuracy: 0.144
# Epoch: 1/5..  Training Loss: 4.131..  Test Loss: 3.786..  Test Accuracy: 0.221
# Epoch: 1/5..  Training Loss: 3.943..  Test Loss: 3.724..  Test Accuracy: 0.214
# Epoch: 1/5..  Training Loss: 3.931..  Test Loss: 3.695..  Test Accuracy: 0.218
# Epoch: 1/5..  Training Loss: 4.029..  Test Loss: 3.659..  Test Accuracy: 0.225
# Epoch: 1/5..  Training Loss: 4.066..  Test Loss: 3.599..  Test Accuracy: 0.243
# Epoch: 1/5..  Training Loss: 3.874..  Test Loss: 3.564..  Test Accuracy: 0.260
# Epoch: 1/5..  Training Loss: 3.918..  Test Loss: 3.529..  Test Accuracy: 0.257
# Epoch: 1/5..  Training Loss: 3.891..  Test Loss: 3.466..  Test Accuracy: 0.239
# Epoch: 1/5..  Training Loss: 3.768..  Test Loss: 3.387..  Test Accuracy: 0.264
# Epoch: 1/5..  Training Loss: 3.883..  Test Loss: 3.347..  Test Accuracy: 0.306
# Epoch: 1/5..  Training Loss: 3.842..  Test Loss: 3.311..  Test Accuracy: 0.273
# Epoch: 2/5..  Training Loss: 3.536..  Test Loss: 3.275..  Test Accuracy: 0.297
# Epoch: 2/5..  Training Loss: 3.695..  Test Loss: 3.272..  Test Accuracy: 0.268
# Epoch: 2/5..  Training Loss: 3.480..  Test Loss: 3.216..  Test Accuracy: 0.298
# Epoch: 2/5..  Training Loss: 3.679..  Test Loss: 3.151..  Test Accuracy: 0.320
# Epoch: 2/5..  Training Loss: 3.565..  Test Loss: 3.136..  Test Accuracy: 0.328
# Epoch: 2/5..  Training Loss: 3.578..  Test Loss: 3.067..  Test Accuracy: 0.312
# Epoch: 2/5..  Training Loss: 3.482..  Test Loss: 3.044..  Test Accuracy: 0.346
# Epoch: 2/5..  Training Loss: 3.474..  Test Loss: 2.966..  Test Accuracy: 0.343
# Epoch: 2/5..  Training Loss: 3.439..  Test Loss: 2.926..  Test Accuracy: 0.374
# Epoch: 2/5..  Training Loss: 3.325..  Test Loss: 2.873..  Test Accuracy: 0.386
# Epoch: 2/5..  Training Loss: 3.256..  Test Loss: 2.874..  Test Accuracy: 0.364
# Epoch: 2/5..  Training Loss: 3.301..  Test Loss: 2.820..  Test Accuracy: 0.346
# Epoch: 2/5..  Training Loss: 3.274..  Test Loss: 2.827..  Test Accuracy: 0.346
# Epoch: 2/5..  Training Loss: 3.411..  Test Loss: 2.752..  Test Accuracy: 0.359
# Epoch: 2/5..  Training Loss: 3.240..  Test Loss: 2.634..  Test Accuracy: 0.407
# Epoch: 2/5..  Training Loss: 3.197..  Test Loss: 2.629..  Test Accuracy: 0.384
# Epoch: 2/5..  Training Loss: 3.282..  Test Loss: 2.585..  Test Accuracy: 0.428
# Epoch: 2/5..  Training Loss: 3.046..  Test Loss: 2.549..  Test Accuracy: 0.419
# Epoch: 2/5..  Training Loss: 2.944..  Test Loss: 2.524..  Test Accuracy: 0.397
# Epoch: 2/5..  Training Loss: 3.330..  Test Loss: 2.437..  Test Accuracy: 0.473
# Epoch: 2/5..  Training Loss: 2.943..  Test Loss: 2.383..  Test Accuracy: 0.442
# Epoch: 2/5..  Training Loss: 3.208..  Test Loss: 2.322..  Test Accuracy: 0.474
# Epoch: 2/5..  Training Loss: 2.918..  Test Loss: 2.374..  Test Accuracy: 0.441
# Epoch: 2/5..  Training Loss: 2.732..  Test Loss: 2.330..  Test Accuracy: 0.459
# Epoch: 2/5..  Training Loss: 2.985..  Test Loss: 2.302..  Test Accuracy: 0.447
# Epoch: 2/5..  Training Loss: 2.828..  Test Loss: 2.241..  Test Accuracy: 0.467
# Epoch: 2/5..  Training Loss: 2.872..  Test Loss: 2.216..  Test Accuracy: 0.489
# Epoch: 2/5..  Training Loss: 2.849..  Test Loss: 2.113..  Test Accuracy: 0.529
# Epoch: 2/5..  Training Loss: 2.718..  Test Loss: 2.148..  Test Accuracy: 0.472
# Epoch: 2/5..  Training Loss: 2.839..  Test Loss: 2.062..  Test Accuracy: 0.494
# Epoch: 2/5..  Training Loss: 2.635..  Test Loss: 2.049..  Test Accuracy: 0.508
# Epoch: 2/5..  Training Loss: 2.676..  Test Loss: 2.011..  Test Accuracy: 0.530
# Epoch: 2/5..  Training Loss: 2.696..  Test Loss: 2.009..  Test Accuracy: 0.517
# Epoch: 2/5..  Training Loss: 2.479..  Test Loss: 2.008..  Test Accuracy: 0.488
# Epoch: 2/5..  Training Loss: 2.523..  Test Loss: 1.987..  Test Accuracy: 0.478
# Epoch: 2/5..  Training Loss: 2.663..  Test Loss: 1.889..  Test Accuracy: 0.532
# Epoch: 2/5..  Training Loss: 2.545..  Test Loss: 1.849..  Test Accuracy: 0.534
# Epoch: 2/5..  Training Loss: 2.615..  Test Loss: 1.850..  Test Accuracy: 0.538
# Epoch: 2/5..  Training Loss: 2.592..  Test Loss: 1.855..  Test Accuracy: 0.567
# Epoch: 2/5..  Training Loss: 2.557..  Test Loss: 1.841..  Test Accuracy: 0.574
# Epoch: 2/5..  Training Loss: 2.454..  Test Loss: 1.893..  Test Accuracy: 0.540
# Epoch: 3/5..  Training Loss: 2.343..  Test Loss: 1.796..  Test Accuracy: 0.517
# Epoch: 3/5..  Training Loss: 2.526..  Test Loss: 1.736..  Test Accuracy: 0.582
# Epoch: 3/5..  Training Loss: 2.513..  Test Loss: 1.684..  Test Accuracy: 0.585
# Epoch: 3/5..  Training Loss: 2.385..  Test Loss: 1.651..  Test Accuracy: 0.587
# Epoch: 3/5..  Training Loss: 2.311..  Test Loss: 1.687..  Test Accuracy: 0.545
# Epoch: 3/5..  Training Loss: 2.371..  Test Loss: 1.630..  Test Accuracy: 0.589
# Epoch: 3/5..  Training Loss: 2.307..  Test Loss: 1.732..  Test Accuracy: 0.524
# Epoch: 3/5..  Training Loss: 2.301..  Test Loss: 1.663..  Test Accuracy: 0.562
# Epoch: 3/5..  Training Loss: 2.081..  Test Loss: 1.586..  Test Accuracy: 0.598
# Epoch: 3/5..  Training Loss: 2.147..  Test Loss: 1.603..  Test Accuracy: 0.573
# Epoch: 3/5..  Training Loss: 2.133..  Test Loss: 1.584..  Test Accuracy: 0.579
# Epoch: 3/5..  Training Loss: 2.045..  Test Loss: 1.585..  Test Accuracy: 0.592
# Epoch: 3/5..  Training Loss: 2.202..  Test Loss: 1.524..  Test Accuracy: 0.622
# Epoch: 3/5..  Training Loss: 1.930..  Test Loss: 1.557..  Test Accuracy: 0.603
# Epoch: 3/5..  Training Loss: 2.231..  Test Loss: 1.486..  Test Accuracy: 0.616
# Epoch: 3/5..  Training Loss: 1.999..  Test Loss: 1.515..  Test Accuracy: 0.593
# Epoch: 3/5..  Training Loss: 1.961..  Test Loss: 1.486..  Test Accuracy: 0.608
# Epoch: 3/5..  Training Loss: 2.078..  Test Loss: 1.527..  Test Accuracy: 0.588
# Epoch: 3/5..  Training Loss: 2.326..  Test Loss: 1.471..  Test Accuracy: 0.603
# Epoch: 3/5..  Training Loss: 1.953..  Test Loss: 1.393..  Test Accuracy: 0.643
# Epoch: 3/5..  Training Loss: 2.104..  Test Loss: 1.385..  Test Accuracy: 0.625
# Epoch: 3/5..  Training Loss: 2.161..  Test Loss: 1.357..  Test Accuracy: 0.650
# Epoch: 3/5..  Training Loss: 1.988..  Test Loss: 1.351..  Test Accuracy: 0.651
# Epoch: 3/5..  Training Loss: 2.000..  Test Loss: 1.288..  Test Accuracy: 0.666
# Epoch: 3/5..  Training Loss: 1.925..  Test Loss: 1.378..  Test Accuracy: 0.616
# Epoch: 3/5..  Training Loss: 2.011..  Test Loss: 1.299..  Test Accuracy: 0.645
# Epoch: 3/5..  Training Loss: 1.655..  Test Loss: 1.314..  Test Accuracy: 0.627
# Epoch: 3/5..  Training Loss: 1.868..  Test Loss: 1.280..  Test Accuracy: 0.656
# Epoch: 3/5..  Training Loss: 1.982..  Test Loss: 1.332..  Test Accuracy: 0.660
# Epoch: 3/5..  Training Loss: 1.998..  Test Loss: 1.276..  Test Accuracy: 0.675
# Epoch: 3/5..  Training Loss: 1.845..  Test Loss: 1.245..  Test Accuracy: 0.657
# Epoch: 3/5..  Training Loss: 1.694..  Test Loss: 1.225..  Test Accuracy: 0.664
# Epoch: 3/5..  Training Loss: 2.084..  Test Loss: 1.263..  Test Accuracy: 0.657
# Epoch: 3/5..  Training Loss: 1.903..  Test Loss: 1.216..  Test Accuracy: 0.688
# Epoch: 3/5..  Training Loss: 1.978..  Test Loss: 1.177..  Test Accuracy: 0.692
# Epoch: 3/5..  Training Loss: 1.883..  Test Loss: 1.159..  Test Accuracy: 0.701
# Epoch: 3/5..  Training Loss: 1.970..  Test Loss: 1.122..  Test Accuracy: 0.699
# Epoch: 3/5..  Training Loss: 1.639..  Test Loss: 1.149..  Test Accuracy: 0.695
# Epoch: 3/5..  Training Loss: 1.822..  Test Loss: 1.129..  Test Accuracy: 0.688
# Epoch: 3/5..  Training Loss: 2.070..  Test Loss: 1.128..  Test Accuracy: 0.714
# Epoch: 3/5..  Training Loss: 1.804..  Test Loss: 1.091..  Test Accuracy: 0.714
# Epoch: 4/5..  Training Loss: 1.693..  Test Loss: 1.092..  Test Accuracy: 0.723
# Epoch: 4/5..  Training Loss: 1.673..  Test Loss: 1.111..  Test Accuracy: 0.703
# Epoch: 4/5..  Training Loss: 1.701..  Test Loss: 1.078..  Test Accuracy: 0.729
# Epoch: 4/5..  Training Loss: 1.773..  Test Loss: 1.135..  Test Accuracy: 0.700
# Epoch: 4/5..  Training Loss: 1.655..  Test Loss: 1.120..  Test Accuracy: 0.704
# Epoch: 4/5..  Training Loss: 1.611..  Test Loss: 1.101..  Test Accuracy: 0.716
# Epoch: 4/5..  Training Loss: 1.483..  Test Loss: 1.076..  Test Accuracy: 0.699
# Epoch: 4/5..  Training Loss: 1.800..  Test Loss: 1.130..  Test Accuracy: 0.696
# Epoch: 4/5..  Training Loss: 1.607..  Test Loss: 1.042..  Test Accuracy: 0.724
# Epoch: 4/5..  Training Loss: 1.645..  Test Loss: 1.103..  Test Accuracy: 0.699
# Epoch: 4/5..  Training Loss: 1.599..  Test Loss: 1.101..  Test Accuracy: 0.688
# Epoch: 4/5..  Training Loss: 1.661..  Test Loss: 1.090..  Test Accuracy: 0.693
# Epoch: 4/5..  Training Loss: 1.659..  Test Loss: 1.080..  Test Accuracy: 0.687
# Epoch: 4/5..  Training Loss: 1.708..  Test Loss: 1.040..  Test Accuracy: 0.710
# Epoch: 4/5..  Training Loss: 1.586..  Test Loss: 0.989..  Test Accuracy: 0.717
# Epoch: 4/5..  Training Loss: 1.621..  Test Loss: 1.011..  Test Accuracy: 0.711
# Epoch: 4/5..  Training Loss: 1.609..  Test Loss: 1.005..  Test Accuracy: 0.730
# Epoch: 4/5..  Training Loss: 1.575..  Test Loss: 0.938..  Test Accuracy: 0.740
# Epoch: 4/5..  Training Loss: 1.661..  Test Loss: 1.012..  Test Accuracy: 0.706
# Epoch: 4/5..  Training Loss: 1.671..  Test Loss: 0.943..  Test Accuracy: 0.722
# Epoch: 4/5..  Training Loss: 1.607..  Test Loss: 0.967..  Test Accuracy: 0.734
# Epoch: 4/5..  Training Loss: 1.471..  Test Loss: 0.941..  Test Accuracy: 0.750
# Epoch: 4/5..  Training Loss: 1.586..  Test Loss: 0.922..  Test Accuracy: 0.751
# Epoch: 4/5..  Training Loss: 1.543..  Test Loss: 0.947..  Test Accuracy: 0.744
# Epoch: 4/5..  Training Loss: 1.613..  Test Loss: 0.919..  Test Accuracy: 0.754
# Epoch: 4/5..  Training Loss: 1.504..  Test Loss: 0.928..  Test Accuracy: 0.738
# Epoch: 4/5..  Training Loss: 1.496..  Test Loss: 1.013..  Test Accuracy: 0.690
# Epoch: 4/5..  Training Loss: 1.513..  Test Loss: 0.909..  Test Accuracy: 0.759
# Epoch: 4/5..  Training Loss: 1.610..  Test Loss: 0.883..  Test Accuracy: 0.748
# Epoch: 4/5..  Training Loss: 1.398..  Test Loss: 0.897..  Test Accuracy: 0.757
# Epoch: 4/5..  Training Loss: 1.629..  Test Loss: 0.928..  Test Accuracy: 0.735
# Epoch: 4/5..  Training Loss: 1.397..  Test Loss: 0.903..  Test Accuracy: 0.752
# Epoch: 4/5..  Training Loss: 1.400..  Test Loss: 0.850..  Test Accuracy: 0.777
# Epoch: 4/5..  Training Loss: 1.510..  Test Loss: 0.831..  Test Accuracy: 0.772
# Epoch: 4/5..  Training Loss: 1.429..  Test Loss: 0.897..  Test Accuracy: 0.764
# Epoch: 4/5..  Training Loss: 1.412..  Test Loss: 0.836..  Test Accuracy: 0.787
# Epoch: 4/5..  Training Loss: 1.420..  Test Loss: 0.842..  Test Accuracy: 0.775
# Epoch: 4/5..  Training Loss: 1.723..  Test Loss: 0.889..  Test Accuracy: 0.759
# Epoch: 4/5..  Training Loss: 1.426..  Test Loss: 0.867..  Test Accuracy: 0.764
# Epoch: 4/5..  Training Loss: 1.757..  Test Loss: 0.838..  Test Accuracy: 0.763
# Epoch: 4/5..  Training Loss: 1.377..  Test Loss: 0.824..  Test Accuracy: 0.771
# Epoch: 5/5..  Training Loss: 1.341..  Test Loss: 0.777..  Test Accuracy: 0.781
# Epoch: 5/5..  Training Loss: 1.469..  Test Loss: 0.797..  Test Accuracy: 0.783
# Epoch: 5/5..  Training Loss: 1.238..  Test Loss: 0.798..  Test Accuracy: 0.788
# Epoch: 5/5..  Training Loss: 1.277..  Test Loss: 0.770..  Test Accuracy: 0.793
# Epoch: 5/5..  Training Loss: 1.316..  Test Loss: 0.801..  Test Accuracy: 0.776
# Epoch: 5/5..  Training Loss: 1.320..  Test Loss: 0.791..  Test Accuracy: 0.783
# Epoch: 5/5..  Training Loss: 1.489..  Test Loss: 0.788..  Test Accuracy: 0.788
# Epoch: 5/5..  Training Loss: 1.390..  Test Loss: 0.806..  Test Accuracy: 0.788
# Epoch: 5/5..  Training Loss: 1.477..  Test Loss: 0.907..  Test Accuracy: 0.736
# Epoch: 5/5..  Training Loss: 1.387..  Test Loss: 0.778..  Test Accuracy: 0.791
# Epoch: 5/5..  Training Loss: 1.294..  Test Loss: 0.755..  Test Accuracy: 0.781
# Epoch: 5/5..  Training Loss: 1.458..  Test Loss: 0.748..  Test Accuracy: 0.799
# Epoch: 5/5..  Training Loss: 1.272..  Test Loss: 0.780..  Test Accuracy: 0.799
# Epoch: 5/5..  Training Loss: 1.225..  Test Loss: 0.769..  Test Accuracy: 0.802
# Epoch: 5/5..  Training Loss: 1.297..  Test Loss: 0.727..  Test Accuracy: 0.807
# Epoch: 5/5..  Training Loss: 1.155..  Test Loss: 0.725..  Test Accuracy: 0.806
# Epoch: 5/5..  Training Loss: 1.412..  Test Loss: 0.714..  Test Accuracy: 0.789
# Epoch: 5/5..  Training Loss: 1.394..  Test Loss: 0.741..  Test Accuracy: 0.797
# Epoch: 5/5..  Training Loss: 1.313..  Test Loss: 0.731..  Test Accuracy: 0.794
# Epoch: 5/5..  Training Loss: 1.211..  Test Loss: 0.762..  Test Accuracy: 0.792
# Epoch: 5/5..  Training Loss: 1.394..  Test Loss: 0.871..  Test Accuracy: 0.745
# Epoch: 5/5..  Training Loss: 1.425..  Test Loss: 0.711..  Test Accuracy: 0.808
# Epoch: 5/5..  Training Loss: 1.420..  Test Loss: 0.695..  Test Accuracy: 0.817
# Epoch: 5/5..  Training Loss: 1.448..  Test Loss: 0.669..  Test Accuracy: 0.829
# Epoch: 5/5..  Training Loss: 1.217..  Test Loss: 0.736..  Test Accuracy: 0.803
# Epoch: 5/5..  Training Loss: 1.173..  Test Loss: 0.699..  Test Accuracy: 0.802
# Epoch: 5/5..  Training Loss: 1.151..  Test Loss: 0.675..  Test Accuracy: 0.820
# Epoch: 5/5..  Training Loss: 1.265..  Test Loss: 0.722..  Test Accuracy: 0.820
# Epoch: 5/5..  Training Loss: 1.273..  Test Loss: 0.690..  Test Accuracy: 0.824
# Epoch: 5/5..  Training Loss: 1.261..  Test Loss: 0.698..  Test Accuracy: 0.807
# Epoch: 5/5..  Training Loss: 1.100..  Test Loss: 0.723..  Test Accuracy: 0.794
# Epoch: 5/5..  Training Loss: 1.283..  Test Loss: 0.681..  Test Accuracy: 0.810
# Epoch: 5/5..  Training Loss: 1.313..  Test Loss: 0.714..  Test Accuracy: 0.798
# Epoch: 5/5..  Training Loss: 1.256..  Test Loss: 0.728..  Test Accuracy: 0.796
# Epoch: 5/5..  Training Loss: 1.138..  Test Loss: 0.718..  Test Accuracy: 0.805
# Epoch: 5/5..  Training Loss: 1.321..  Test Loss: 0.701..  Test Accuracy: 0.810
# Epoch: 5/5..  Training Loss: 1.182..  Test Loss: 0.667..  Test Accuracy: 0.811
# Epoch: 5/5..  Training Loss: 1.078..  Test Loss: 0.689..  Test Accuracy: 0.808
# Epoch: 5/5..  Training Loss: 1.230..  Test Loss: 0.644..  Test Accuracy: 0.818
# Epoch: 5/5..  Training Loss: 1.180..  Test Loss: 0.683..  Test Accuracy: 0.798
# Epoch: 5/5..  Training Loss: 1.486..  Test Loss: 0.696..  Test Accuracy: 0.806

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
model.eval()

test_loss, accuracy = validation(model, loaders['test'], criterion, device)

test_loss_med = test_loss / len(loaders['test'])
accuracy_med = accuracy / len(loaders['test'])

print(f"Test accuracy (%): {accuracy_med*100:.3f}")
# Out:
# Test accuracy (%): 78.315

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
def save_checkpoint(learning_rate, epochs, optimizer, model, output_size, hidden_layers, momentum):
    checkpoint = {
        'epoch' : epochs,
        'learning_rate': learning_rate,
        'optimizer_state_dict': optimizer.state_dict(),
        'class_to_idx': model.class_to_idx,
        'output_size' : output_size,
        'hidden_layers': hidden_layers,
        'model_state_dict' : model.state_dict(),
        'momentum': momentum
    }

    torch.save(checkpoint, 'checkpoint.pth')

# %%
model.class_to_idx = image_datasets['train'].class_to_idx

save_checkpoint(learning_rate, epochs, optimizer, model, 102, hidden_layers, momentum)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
criterion = nn.CrossEntropyLoss()

def load_checkpoint(path):
    _device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    _checkpoint = torch.load(path, map_location='cpu')
    _model = models.vgg16(pretrained=True)
    
    for params in _model.parameters():
        params.requires_grad = False
    
    create_classifier(_model, _checkpoint['hidden_layers'])
    
    _model.load_state_dict(_checkpoint['model_state_dict'])
    _model.class_to_idx = _checkpoint['class_to_idx']
    _optimizer = optim.SGD(_model.classifier.parameters(), lr=_checkpoint['learning_rate'], momentum=_checkpoint['momentum'])
    _optimizer.load_state_dict(_checkpoint['optimizer_state_dict'])
    _model.to(_device)
    return _model, _optimizer, _checkpoint['epoch']


model_loaded, optimizer, epochs = load_checkpoint('checkpoint.pth')

# %%
#Testing that model has been correctly loaded

model_loaded.eval()
test_loss, accuracy = validation(model_loaded, loaders['test'], criterion, torch.device("cuda" if torch.cuda.is_available() else "cpu"))

accuracy_med = accuracy / len(loaders['test'])

print(f"Test accuracy (%): {accuracy_med*100:.3f}")
# Out:
# Test accuracy (%): 78.315

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    transform_img = transforms.Compose([
        transforms.Resize(255),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    
    img = transform_img(image)
    

    return img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
image = Image.open('flowers/test/28/image_05270.jpg')
np_image = process_image(image)
imshow(np_image)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
from torch.autograd import Variable

def predict(image_path, model, topk=5, normalized=True):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.eval()
    image = Image.open(image_path)
    image = process_image(image)
    inputs = Variable(image.unsqueeze(0))    
    output = model(inputs.cuda() if torch.cuda.is_available() else np_image.cpu())
    ps = torch.exp(output)
    top_p, top_class = ps.topk(topk, dim=1)
    inv_map = {v: k for k, v in model.class_to_idx.items()}
    top_p = top_p.tolist()[0]
    top_class = [inv_map[i] for i in top_class.tolist()[0]]
    if normalized:
        total = np.sum(top_p)
        top_p = top_p / total
    return top_p, top_class
    
probs, classes = predict('flowers/test/28/image_05270.jpg', model_loaded)
print(probs)
print(classes)
# Out:
# [0.81625322 0.10761681 0.03523185 0.0273008  0.01359732]
# ['28', '9', '45', '3', '76']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def plot_image(image_path, model, to):
    fig, (ax1, ax2) = plt.subplots(figsize=(7,7), nrows = 2)
    probs, classes = predict(image_path, model)
    mapped = [to[i] for i in classes]
    ax2.barh(mapped, probs * 100)
    image = Image.open(image_path)
    imshow(process_image(image), ax=ax1)

# %%
plot_image('flowers/test/28/image_05270.jpg', model_loaded, cat_to_name)
